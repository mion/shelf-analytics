# %%
# In order to import event extraction module...
import sys
sys.path.append('/Users/gvieira/code/toneto/shan')

# %%
import math
import random
import numpy as np

import matplotlib.pyplot as plt

# %%
def make_noisy(seq, amp=0.2, delta=None): # seq is a numpy array
    random.seed(1) # ensure some determinism
    delta = abs(seq.max() - seq.min()) if delta is None else delta
    noise_amp = amp * delta
    return np.array([(y + (random.random()*noise_amp/2) - (random.random()*noise_amp/2)) for y in seq])

# %%
def plot(seq):
    plt.scatter([i for i in range(len(seq))], seq)

# %%
#
# Small peak big peak
#
seq = [math.pow(i, 3) for i in range(15)] + [math.pow(15 - i, 3) for i in range(15)] + [math.pow(i, 2.5) for i in range(15)] + [math.pow(15 - i, 2.5) for i in range(15)]
seq.reverse()
small_peak_big_peak = make_noisy(np.array(seq), amp=0.35)
plot(small_peak_big_peak)

# %%
#
# Short step
#
seq = [100*i for i in range(15)] + [100*15 for i in range(15, 30)] + [100*(45 - i) for i in range(30, 45)]
short_step = make_noisy(np.array(seq), amp=0.65)
plot(short_step)

# %%
#
# Long step
#
seq = [100*i for i in range(10)] + [100*10 for i in range(10, 100)] + [100*(110 - i) for i in range(100, 110)]
long_step = make_noisy(np.array(seq), amp=0.45)
plot(long_step)

# %% [markdown]
# ### Signals used for testing

# %%
# This is generated in the `extract_events` test:
plot([0, 100, 400, 900, 1600, 2500, 3600, 4900, 6400, 8100, 10000, 9900, 9600, 9100, 8400, 7500, 6400, 5100, 3600, 1900, 0])

# %%
plot([0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500, 1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000, 2050, 2100, 2150, 2200, 2250, 2300, 2350, 2400, 2450, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2500, 2450, 2400, 2350, 2300, 2250, 2200, 2150, 2100, 2050, 2000, 1950, 1900, 1850, 1800, 1750, 1700, 1650, 1600, 1550, 1500, 1450, 1400, 1350, 1300, 1250, 1200, 1150, 1100, 1050, 1000, 950, 900, 850, 800, 750, 700, 650, 600, 550, 500, 450, 400, 350, 300, 250, 200, 150, 100, 50, 0])
